# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Chargement du fichier csv
data = pd.read_csv("TB_ETUDIANT.csv", encoding='latin-1', delimiter=";")


#Appercu des données
print(data.head())

df = pd.DataFrame(data)

# Extraction des variables numériques

numeric_variables = ['MoyenneBac', 'NotesMaths', 'NotesFrançais', 'NotesPhysChimie', 'NotesSVT', 'NotesAnglais']
numeric_data = df[numeric_variables]
# Out:
#   ID_ETUDIANT Sexe  MoyenneBac  NotesMaths  NotesFrançais  NotesPhysChimie  \
# 0       ET001    F        15.0        16.0           16.0            12.75
# 1       ET002    F        10.0         7.0           15.0            20.00
# 2       ET003    F        10.0        14.0           17.0            17.00
# 3       ET004    F        15.0         7.0           16.0            12.75
# 4       ET005    F        12.0         9.0           13.0            19.00
#
#    NotesSVT  NotesAnglais     Interets1         Interets2  Orientation Licence
# 0       8.0           6.0   agriculture  agro-alimentaire    agronomie     oui
# 1      20.0          13.0        Chimie        sociologie     Biologie     oui
# 2      17.0           9.0  Architecture     Mathematiques  Genie civil     oui
# 3       8.0          19.0  Informatique        Multimedia  Agriculture     non
# 4      19.0          15.0    sociologie        Sociologie     Medecine     oui

# %%
# Statistiques descriptives
print(data.describe(), 2)
# Out:
#         MoyenneBac   NotesMaths  NotesFrançais  NotesPhysChimie     NotesSVT  \
# count  1147.000000  1147.000000    1147.000000      1147.000000  1147.000000
# mean     12.621543    12.963819      13.812990        13.555798    13.620532
# std       2.095266     4.153023       3.451264         3.595546     3.631327
# min      10.000000     6.000000       8.000000         8.500000     7.000000
# 25%      11.000000    10.000000      11.000000        10.000000    11.000000
# 50%      12.000000    13.000000      13.000000        13.000000    13.000000
# 75%      14.000000    16.000000      17.000000        17.000000    17.000000
# max      19.000000    20.000000      20.000000        20.000000    20.000000
#
#        NotesAnglais
# count   1147.000000
# mean      13.307323
# std        3.749161
# min        6.000000
# 25%       11.000000
# 50%       13.000000
# 75%       17.000000
# max       19.000000   2

# %%
data['MoyenneBac'].hist()
plt.title('distiribution de la variable')
plt.show()

# %%
# One-hot encoding for 'Sexe' variable
df_encoded = pd.get_dummies(df, columns=['Sexe'], drop_first=True)

# Calculate correlation matrix
correlation_matrix = df_encoded[['MoyenneBac', 'NotesMaths', 'NotesFrançais', 'NotesPhysChimie', 'NotesSVT', 'NotesAnglais', 'Sexe_M']].corr()

# Plot correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matrice de correlation')
plt.show()

# %%
# Nomde valeurs manquantes par colonnes

print(data.isnull().sum())
# Out:
# ID_ETUDIANT        0
# Sexe               0
# MoyenneBac         0
# NotesMaths         0
# NotesFrançais      0
# NotesPhysChimie    0
# NotesSVT           0
# NotesAnglais       0
# Interets1          0
# Interets2          0
# Orientation        0
# Licence            0
# dtype: int64

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.Sexe.describe()

df.Sexe.unique()

df.Sexe.value_counts()

pd.crosstab(df.Sexe, "freq")

pd.crosstab(df.Sexe, "freq", normalize=True)
# Out:
# col_0      freq
# Sexe
# F      0.534438
# M      0.465562

# %%
df.Licence.describe()

df.Licence.unique()

df.Licence.value_counts()

pd.crosstab(df.Licence, "freq")

pd.crosstab(df.Licence, "freq", normalize=True)
# Out:
# col_0        freq
# Licence
# non      0.397559
# oui      0.602441

# %%
etud = pd.crosstab(df.Licence, "freq")
etud.plot.bar()
# Out:
# <Axes: xlabel='Licence'>

# %%
etud = pd.crosstab(df.Sexe, "freq")
etud.plot.bar()
# Out:
# <Axes: xlabel='Sexe'>

# %%
etud.plot(kind= "bar")
# Out:
# <Axes: xlabel='Sexe'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1147 entries, 0 to 1146
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID_ETUDIANT      1147 non-null   object
#  1   Sexe             1147 non-null   object
#  2   MoyenneBac       1147 non-null   float64
#  3   NotesMaths       1147 non-null   float64
#  4   NotesFrançais    1147 non-null   float64
#  5   NotesPhysChimie  1147 non-null   float64
#  6   NotesSVT         1147 non-null   float64
#  7   NotesAnglais     1147 non-null   float64
#  8   Interets1        1147 non-null   object
#  9   Interets2        1147 non-null   object
#  10  Orientation      1147 non-null   object
#  11  Licence          1147 non-null   object
# dtypes: float64(6), object(6)
# memory usage: 107.7+ KB
