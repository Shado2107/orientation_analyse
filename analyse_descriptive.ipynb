# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Chargement du fichier csv
data = pd.read_csv("TB_ETUDIANT.csv", encoding='latin-1', delimiter=";")


#Appercu des données
print(data.head())

df = pd.DataFrame(data)

# Extraction des variables numériques

numeric_variables = ['MoyenneBac', 'NotesMaths', 'NotesFrançais', 'NotesPhysChimie', 'NotesSVT', 'NotesAnglais']
numeric_data = df[numeric_variables]
# Out:
#   ID_ETUDIANT Sexe  MoyenneBac Orientation  NotesMaths  NotesFrançais  \
# 0       ET001    F        15.0           L        16.0           16.0
# 1       ET002    F        10.0           S         7.0           15.0
# 2       ET003    F        10.0           S        14.0           17.0
# 3       ET004    F        15.0           S         7.0           16.0
# 4       ET005    F        12.0           S         9.0           13.0
#
#    NotesPhysChimie  NotesSVT  NotesAnglais     Interets1         Interets2  \
# 0            12.75       8.0           6.0   agriculture  agro-alimentaire
# 1            20.00      20.0          13.0        Chimie        sociologie
# 2            17.00      17.0           9.0  Architecture     Mathematiques
# 3            12.75       8.0          19.0  Informatique        Multimedia
# 4            19.00      19.0          15.0    sociologie            Social
#
#   choixOrientation Licence
# 0        agronomie     oui
# 1         Biologie     oui
# 2      Genie civil     oui
# 3     Informatique     non
# 4         Medecine     oui

# %%
# Statistiques descriptives
print(data.describe(), 2)
# Out:
#         MoyenneBac   NotesMaths  NotesFrançais  NotesPhysChimie     NotesSVT  \
# count  1147.000000  1147.000000    1147.000000      1147.000000  1147.000000
# mean     12.621543    12.963819      13.812990        13.555798    13.620532
# std       2.095266     4.153023       3.451264         3.595546     3.631327
# min      10.000000     6.000000       8.000000         8.500000     7.000000
# 25%      11.000000    10.000000      11.000000        10.000000    11.000000
# 50%      12.000000    13.000000      13.000000        13.000000    13.000000
# 75%      14.000000    16.000000      17.000000        17.000000    17.000000
# max      19.000000    20.000000      20.000000        20.000000    20.000000
#
#        NotesAnglais
# count   1147.000000
# mean      13.307323
# std        3.749161
# min        6.000000
# 25%       11.000000
# 50%       13.000000
# 75%       17.000000
# max       19.000000   2

# %%
data['MoyenneBac'].hist()
plt.title('distiribution de la variable')
plt.show()

# %%
# Corrélations

correlation_matrix = numeric_data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f' )
plt.title('Matrice de correlation')
plt.show()

# %%
# Nomde valeurs manquantes par colonnes

print(data.isnull().sum())
# Out:
# ID_ETUDIANT         0
# Sexe                0
# MoyenneBac          0
# Orientation         0
# NotesMaths          0
# NotesFrançais       0
# NotesPhysChimie     0
# NotesSVT            0
# NotesAnglais        0
# Interets1           0
# Interets2           0
# choixOrientation    0
# Licence             0
# dtype: int64

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.Sexe.describe()

df.Sexe.unique()

df.Sexe.value_counts()

pd.crosstab(df.Sexe, "freq")

pd.crosstab(df.Sexe, "freq", normalize=True)
# Out:
# col_0      freq
# Sexe
# F      0.534438
# M      0.465562

# %%
etud = pd.crosstab(df.Sexe, "freq")
etud.plot.bar()
# Out:
# <Axes: xlabel='Sexe'>

# %%
etud.plot(kind= "bar")
# Out:
# <Axes: xlabel='Sexe'>
